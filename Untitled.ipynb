# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np 
import math 
import seaborn as sn

# %% [markdown]
# ### Get Dataset

# %%
# get bag of words
data = pd.read_csv('Dataset/BOW/test.csv', header = None)

# get labels
dataset = pd.read_csv('Dataset/train.csv')[['text', 'label']]
dataset.dropna(inplace = True)
dataset.reset_index(drop = True, inplace = True)
label = dataset['label'].head(len(data))

# %% [markdown]
# ### Sigmoid Function
#
# ![image.png](attachment:image.png)

# %%
x = np.linspace(-10, 10, 100) 
z = 1/(1 + np.exp(-x)) 
  
plt.plot(x, z) 
plt.xlabel("x") 
plt.ylabel("Sigmoid(X)") 
  
plt.show()

# %% [markdown]
# ### Cost Function
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Gradient Descent
# ![image.png](attachment:image.png)

# %%
# Note: 0.0000001 is used so the log(1 - h) will not return log(0)

def hypothesis(X, theta):
    z = np.dot(theta, X.T)
    return 1/(1+np.exp(-(z))) - 0.0000001

# %%
def cost(X, y, theta):
    y1 = hypothesis(X, theta)
    return -(1/len(X)) * np.sum(y*np.log(y1) + (1-y)*np.log(1-y1))

# %%
def gradient_descent(X, y, theta, alpha, epochs):
    m =len(X)
    J = [cost(X, y, theta)] 
    for i in range(0, epochs):
        h = hypothesis(X, theta)
        for i in range(0, len(X.columns)):
            theta[i] -= (alpha/m) * np.sum((h-y)*X.iloc[:, i])
        J.append(cost(X, y, theta))
    return J, theta

# %%
def predict(X, y, theta, alpha, epochs):
    J, th = gradient_descent(X, y, theta, alpha, epochs) 
    h = hypothesis(X, theta)
    for i in range(len(h)):
        h[i]=1 if h[i]>=0.5 else 0
    y = list(y)
    acc = np.sum([y[i] == h[i] for i in range(len(y))])/len(y)
    return J, acc

# %%
theta = [0.5]*len(data.columns)
J, acc = predict(data, label, theta,0.0001, 100)

# %%
acc
# Out:
# 0.47

# %%
plt.figure(figsize = (12, 8))
plt.scatter(range(0, len(J)), J)
plt.show()
